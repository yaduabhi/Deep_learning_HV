# %% [markdown]
# # Assignment 1: Introduction to Neural Networks
#
# ## Objectives
# - Understand the basic structure of neural networks
# - Implement a simple perceptron from scratch
# - Build a multi-layer neural network using NumPy
# - Train a neural network on a simple dataset
#
# ## Prerequisites
# - Python 3.x
# - NumPy
# - Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# %% [markdown]
# ## Part 1: Single Perceptron
#
# A perceptron is the simplest form of a neural network. It takes multiple inputs, applies weights to them, and produces a single output.
#
# ### Task 1.1: Implement the Sigmoid Activation Function
#
# The sigmoid function is defined as: σ(x) = 1 / (1 + e^(-x))

# %%
def sigmoid(x):
    """Compute the sigmoid activation function.
    
    Args:
        x: Input value or array
        
    Returns:
        Sigmoid of x
    """
    # TODO: Implement the sigmoid function
    pass

def sigmoid_derivative(x):
    """Compute the derivative of the sigmoid function.
    
    Args:
        x: Input value or array (already passed through sigmoid)
        
    Returns:
        Derivative of sigmoid at x
    """
    # TODO: Implement the sigmoid derivative
    pass

# %% [markdown]
# ### Task 1.2: Implement a Simple Perceptron Class

# %%
class Perceptron:
    """A simple perceptron implementation."""
    
    def __init__(self, input_size, learning_rate=0.1):
        """Initialize the perceptron.
        
        Args:
            input_size: Number of input features
            learning_rate: Learning rate for weight updates
        """
        # TODO: Initialize weights and bias randomly
        self.weights = None
        self.bias = None
        self.learning_rate = learning_rate
    
    def forward(self, x):
        """Compute the forward pass.
        
        Args:
            x: Input features
            
        Returns:
            Output after activation
        """
        # TODO: Implement forward pass
        pass
    
    def train(self, X, y, epochs=100):
        """Train the perceptron.
        
        Args:
            X: Training features
            y: Training labels
            epochs: Number of training epochs
            
        Returns:
            List of losses for each epoch
        """
        losses = []
        # TODO: Implement training loop
        return losses

# %% [markdown]
# ## Part 2: Multi-Layer Neural Network
#
# ### Task 2.1: Implement a Two-Layer Neural Network

# %%
class NeuralNetwork:
    """A simple two-layer neural network."""
    
    def __init__(self, input_size, hidden_size, output_size, learning_rate=0.1):
        """Initialize the neural network.
        
        Args:
            input_size: Number of input features
            hidden_size: Number of neurons in hidden layer
            output_size: Number of output neurons
            learning_rate: Learning rate for weight updates
        """
        # TODO: Initialize weights and biases for both layers
        self.W1 = None
        self.b1 = None
        self.W2 = None
        self.b2 = None
        self.learning_rate = learning_rate
    
    def forward(self, X):
        """Compute the forward pass.
        
        Args:
            X: Input features
            
        Returns:
            Output predictions
        """
        # TODO: Implement forward pass through both layers
        pass
    
    def backward(self, X, y, output):
        """Compute the backward pass and update weights.
        
        Args:
            X: Input features
            y: True labels
            output: Predicted output from forward pass
        """
        # TODO: Implement backpropagation
        pass
    
    def train(self, X, y, epochs=1000):
        """Train the neural network.
        
        Args:
            X: Training features
            y: Training labels
            epochs: Number of training epochs
            
        Returns:
            List of losses for each epoch
        """
        losses = []
        # TODO: Implement training loop
        return losses

# %% [markdown]
# ## Part 3: Training on XOR Dataset
#
# The XOR problem is a classic example that cannot be solved by a single perceptron but can be solved by a multi-layer neural network.
#
# ### Task 3.1: Create XOR Dataset and Train the Network

# %%
# XOR dataset
X_xor = np.array([[0, 0],
                  [0, 1],
                  [1, 0],
                  [1, 1]])

y_xor = np.array([[0],
                  [1],
                  [1],
                  [0]])

# TODO: Create and train a neural network on the XOR dataset
# nn = NeuralNetwork(input_size=2, hidden_size=4, output_size=1)
# losses = nn.train(X_xor, y_xor, epochs=10000)

# %% [markdown]
# ### Task 3.2: Visualize the Training Loss

# %%
# TODO: Plot the training loss curve
# plt.figure(figsize=(10, 6))
# plt.plot(losses)
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Training Loss over Epochs')
# plt.show()

# %% [markdown]
# ## Part 4: Questions
#
# Answer the following questions:
#
# 1. Why can't a single perceptron solve the XOR problem?
#
# 2. What is the role of the activation function in a neural network?
#
# 3. What happens if the learning rate is too high or too low?
#
# 4. How does the number of neurons in the hidden layer affect the network's performance?

# %% [markdown]
# ## Submission
#
# Please submit:
# 1. This completed notebook with all code implemented
# 2. Answers to all questions
# 3. Training loss plots
